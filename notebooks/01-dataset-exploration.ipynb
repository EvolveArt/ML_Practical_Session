# %% [markdown]
# # Exploration of the MNIST Dataset

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Snippet for the use of relative imports
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.visualization.visualize import plot_samples, X, Y

plot_samples()

# %%
X.shape
# Out:
# (70000, 28, 28)

# %%
Y.shape
# Out:
# (70000,)

# %% [markdown]
# Let's split out data into train and test datasets using sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
# 80% train - 20% test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)

# %%
X_train.shape
# Out:
# (56000, 28, 28)

# %% [markdown]
# But is our data well balanced ? Do we have an even amount of each digit to train our model with ?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(Y_train)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Seems to be pretty good with around 5000/6000k training samples for each digit

# %%
import numpy as np
import seaborn as sns

image = X_train[25]
sns.displot(image)
